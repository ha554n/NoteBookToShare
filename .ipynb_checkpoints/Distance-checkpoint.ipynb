# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# # Initial Reqs

# %%
#packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import os
import math
from itertools import combinations_with_replacement
import pickle
from IPython.display import display
pd.set_option('display.max_rows', 500)
pd.options.display.max_colwidth=100
from natsort import natsorted
import seaborn as sns
import scipy.stats as stats 
from collections import Counter
from itertools import groupby
from operator import itemgetter
from itertools import combinations
import time
import datetime
import choix
import plotly.graph_objects as go
from tqdm import tqdm
from decimal import Decimal

# %% [markdown]
# # Functions

# %%
def radarPlotDF(countsdf,maxpt,title,**kwargs):
    """
    makes a radar plot from a dataframe with the first two columns being
    used as 'pre' and 'post

    countssdf: a 2 column dataframe with counts
    maxpt: how to scale

    optional-
    colorcode: put color code or not? 'on' if yes.
    """
    colorcode=kwargs.get('colorcode',None)
    #set up colors
    hues=np.linspace(0,1,16,endpoint=False)
    hues=['%1.2f' % i for i in hues]
    hues=[float(i) for i in hues]
    colors = plt.cm.hsv(hues)
    # Compute pie slices
    N = 16
    theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
    radii = np.repeat(1,N)
    width = np.repeat(0.25,N)

    #set up data
    counts_df1=countsdf.iloc[:,0]
    counts_df2=countsdf.iloc[:,1]
    categories1=[str(i) for i in counts_df1.index]#cars
    N = len(categories1)
    #cars
    values1=[i for i in counts_df1.values]
    values1 += values1[:1] #makes it circular
    values2=[i for i in counts_df2.values]
    values2 += values2[:1] #makes it circular
    # What will be the angle of each axis in the plot? (we divide the plot / number of variable)
    #this doesn't change for all. all have 16 data points
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]
    # Initialise the spider plot
    ax = plt.subplot(111, polar=True)
    # Draw one axe per variable + add labels labels yet
    plt.xticks(angles[:-1], categories1, color='grey', size=8)
    # Draw ylabels
    ax.set_rlabel_position(0)
    plt.yticks([i for i in np.arange(0,maxpt)],[],color="black", size=5)
    plt.ylim(0,maxpt)
    # Plot data
    ax.plot(angles, values1, linewidth=1, linestyle='solid')
    ax.plot(angles, values2, linewidth=1, linestyle='solid')
    # Fill area
    ax.fill(angles, values1, 'b', alpha=0.1)
    ax.fill(angles, values2, 'r', alpha=0.1)
    if colorcode=='on':
      bars = ax.bar(theta, radii, width=width, bottom=15, color=colors)
    ax.legend(['Pre','Post'])
    plt.title(title)
   
def interactiveRadar(countsDF,subname,category):
    counts_df1=countsDF.iloc[:,0]#pre
    counts_df2=countsDF.iloc[:,1]#post
    counts_df3=countsDF.iloc[:,2]#pre
    categories1=[str(i)[0:7] for i in counts_df1.index]#shirts
    N = len(categories1)

    values1=[i for i in counts_df1.values]
    values1 += values1[:1] #makes it circular
    values2=[i for i in counts_df2.values]
    values2 += values2[:1] #makes it circular
    values3=[i for i in counts_df3.values]
    values3 += values3[:1] #makes it circular


    fig = go.Figure()
    
    #plot pre
    fig.add_trace(go.Scatterpolar(
        opacity=0.75,
          r=values1,
          theta=categories1,
          fill='toself',
          name='Pre'
    ))
    #plot post
    fig.add_trace(go.Scatterpolar(
        opacity=0.75,
          r=values2,
          theta=categories1,
          fill='toself',
          name='Post '
    ))
    #plot follow-up
    fig.add_trace(go.Scatterpolar(
        opacity=0.75,
        r=values3,
        theta=categories1,
        fill='toself',
        name='3 Day '
    ))

    fig.update_layout(
    title=subname+' '+ category,
      polar=dict(
        radialaxis=dict(
          visible=True,
            showline=False,
              range=[0, 16]
        )),
      showlegend=True
    )

    fig.show()

def getPscore(data,score):
    pscore=stats.percentileofscore(data,score,kind='mean')
    return(pscore/100)

def colorcode(value):
  """
  Colors elements in a dateframe
  green if over 0.95
  """
  if value > 0.99 or value < 0.01:
    color = 'green'
  else:
    color = 'black'

  return 'color: %s' % color

from decimal import Decimal # Decimal used for extra precision

def coordinates_of_triangle_given_SSS(a, b, c):
    """a, b and c are lengths of the sides of a triangle
    https://math.stackexchange.com/questions/2480560/computing-coordinates-of-vertices-in-a-sss-triangle
    """

    A = (0, 0) # coordinates of vertex A

    B = (c, 0) # coordinates of vertex B

    C_x = b * (b**2 + c**2 - a**2) / (2 * b * c)
    C_y = Decimal(b**2 - C_x**2).sqrt() # square root

    C = (float(C_x), float(C_y)) # coordinates of vertex C

    # print
    vertices = np.array([A, B, C,A])
    return(vertices)

# %% [markdown]
# # Load Subjects

# %%
#subject clas for loading
class Subject():
    def __init__(self,subname):
        self.subname=subname
#load
os.chdir(r"C:\Users\al33m\Google Drive\GU Neuroaesthetics Lab\AestheticStability\SubDicts\first_visit")
subs={}
for i in ['sub'+str(i) for i in np.arange(1,12)]:
    print(i)
    with open(i+'.pkl', 'rb') as input:
        subs[i] = pickle.load(input)
# Out:
# sub1
# sub2
# sub3
# sub4
# sub5
# sub6
# sub7
# sub8
# sub9
# sub10
# sub11

# %%
class FUPSubject():
    """
    had to create a new class for followup because prolific Id's are not aligned, future iteration should just be one class
    """
    def __init__(self,subname):
        self.subname=subname
#load
os.chdir(r"C:\Users\al33m\Google Drive\GU Neuroaesthetics Lab\AestheticStability\SubDicts\follow_up")
FUPsubs={}
for i in ['sub'+str(i) for i in [2,3,5,6,7,8,9,10,11]]:
    print(i)
    with open(i+'.pkl', 'rb') as input:
        FUPsubs[i] = pickle.load(input)
# Out:
# sub2
# sub3
# sub5
# sub6
# sub7
# sub8
# sub9
# sub10
# sub11

# %% [markdown]
# # General Subject Data

# %% [markdown]
# I am saving subject data along with other measures to be shared in the future in a box folder entitled 'forNG'. Below is what the folder structure looks like

# %%
def list_files(startpath):
    for root, dirs, files in os.walk(startpath):
        level = root.replace(startpath, '').count(os.sep)
        indent = ' ' * 4 * (level)
        print('{}{}/'.format(indent, os.path.basename(root)))
        subindent = ' ' * 4 * (level + 1)
        for f in files:
            print('{}{}'.format(subindent, f))

# %%
from pathlib import Path

class DisplayablePath(object):
    display_filename_prefix_middle = '├──'
    display_filename_prefix_last = '└──'
    display_parent_prefix_middle = '    '
    display_parent_prefix_last = '│   '

    def __init__(self, path, parent_path, is_last):
        self.path = Path(str(path))
        self.parent = parent_path
        self.is_last = is_last
        if self.parent:
            self.depth = self.parent.depth + 1
        else:
            self.depth = 0

    @property
    def displayname(self):
        if self.path.is_dir():
            return self.path.name + '/'
        return self.path.name

    @classmethod
    def make_tree(cls, root, parent=None, is_last=False, criteria=None):
        root = Path(str(root))
        criteria = criteria or cls._default_criteria

        displayable_root = cls(root, parent, is_last)
        yield displayable_root

        children = sorted(list(path
                               for path in root.iterdir()
                               if criteria(path)),
                          key=lambda s: str(s).lower())
        count = 1
        for path in children:
            is_last = count == len(children)
            if path.is_dir():
                yield from cls.make_tree(path,
                                         parent=displayable_root,
                                         is_last=is_last,
                                         criteria=criteria)
            else:
                yield cls(path, displayable_root, is_last)
            count += 1

    @classmethod
    def _default_criteria(cls, path):
        return True

    @property
    def displayname(self):
        if self.path.is_dir():
            return self.path.name + '/'
        return self.path.name

    def displayable(self):
        if self.parent is None:
            return self.displayname

        _filename_prefix = (self.display_filename_prefix_last
                            if self.is_last
                            else self.display_filename_prefix_middle)

        parts = ['{!s} {!s}'.format(_filename_prefix,
                                    self.displayname)]

        parent = self.parent
        while parent and parent.parent is not None:
            parts.append(self.display_parent_prefix_middle
                         if parent.is_last
                         else self.display_parent_prefix_last)
            parent = parent.parent

        return ''.join(reversed(parts))

# %%
paths = DisplayablePath.make_tree(Path(r"C:\Users\al33m\Google Drive\GU Neuroaesthetics Lab\forNG"))
for path in paths:
    print(path.displayable())
# Out:
# forNG/
# ├── desktop.ini
# └── Subject_Data/
#     ├── CompMat/
#     │   ├── Cars/
#     │   │   ├── A/
#     │   │   │   ├── desktop.ini
#     │   │   │   ├── sub10A_CarsCompMat.csv
#     │   │   │   ├── sub11A_CarsCompMat.csv
#     │   │   │   ├── sub1A_CarsCompMat.csv
#     │   │   │   ├── sub2A_CarsCompMat.csv
#     │   │   │   ├── sub3A_CarsCompMat.csv
#     │   │   │   ├── sub4A_CarsCompMat.csv
#     │   │   │   ├── sub5A_CarsCompMat.csv
#     │   │   │   ├── sub6A_CarsCompMat.csv
#     │   │   │   ├── sub7A_CarsCompMat.csv
#     │   │   │   ├── sub8A_CarsCompMat.csv
#     │   │   │   └── sub9A_CarsCompMat.csv
#     │   │   ├── B/
#     │   │   │   ├── desktop.ini
#     │   │   │   ├── sub10B_CarsCompMat.csv
#     │   │   │   ├── sub11B_CarsCompMat.csv
#     │   │   │   ├── sub1B_CarsCompMat.csv
#     │   │   │   ├── sub2B_CarsCompMat.csv
#     │   │   │   ├── sub3B_CarsCompMat.csv
#     │   │   │   ├── sub4B_CarsCompMat.csv
#     │   │   │   ├── sub5B_CarsCompMat.csv
#     │   │   │   ├── sub6B_CarsCompMat.csv
#     │   │   │   ├── sub7B_CarsCompMat.csv
#     │   │   │   ├── sub8B_CarsCompMat.csv
#     │   │   │   └── sub9B_CarsCompMat.csv
#     │   │   ├── C/
#     │   │   │   ├── desktop.ini
#     │   │   │   ├── sub10C_CarsCompMat.csv
#     │   │   │   ├── sub11C_CarsCompMat.csv
#     │   │   │   ├── sub2C_CarsCompMat.csv
#     │   │   │   ├── sub3C_CarsCompMat.csv
#     │   │   │   ├── sub5C_CarsCompMat.csv
#     │   │   │   ├── sub6C_CarsCompMat.csv
#     │   │   │   ├── sub7C_CarsCompMat.csv
#     │   │   │   ├── sub8C_CarsCompMat.csv
#     │   │   │   └── sub9C_CarsCompMat.csv
#     │   │   └── desktop.ini
#     │   ├── desktop.ini
#     │   └── Shirts/
#     │       ├── A/
#     │       │   ├── desktop.ini
#     │       │   ├── sub10A_ShirtsCompMat.csv
#     │       │   ├── sub11A_ShirtsCompMat.csv
#     │       │   ├── sub1A_ShirtsCompMat.csv
#     │       │   ├── sub2A_ShirtsCompMat.csv
#     │       │   ├── sub3A_ShirtsCompMat.csv
#     │       │   ├── sub4A_ShirtsCompMat.csv
#     │       │   ├── sub5A_ShirtsCompMat.csv
#     │       │   ├── sub6A_ShirtsCompMat.csv
#     │       │   ├── sub7A_ShirtsCompMat.csv
#     │       │   ├── sub8A_ShirtsCompMat.csv
#     │       │   └── sub9A_ShirtsCompMat.csv
#     │       ├── B/
#     │       │   ├── desktop.ini
#     │       │   ├── sub10B_ShirtsCompMat.csv
#     │       │   ├── sub11B_ShirtsCompMat.csv
#     │       │   ├── sub1B_ShirtsCompMat.csv
#     │       │   ├── sub2B_ShirtsCompMat.csv
#     │       │   ├── sub3B_ShirtsCompMat.csv
#     │       │   ├── sub4B_ShirtsCompMat.csv
#     │       │   ├── sub5B_ShirtsCompMat.csv
#     │       │   ├── sub6B_ShirtsCompMat.csv
#     │       │   ├── sub7B_ShirtsCompMat.csv
#     │       │   ├── sub8B_ShirtsCompMat.csv
#     │       │   └── sub9B_ShirtsCompMat.csv
#     │       ├── C/
#     │       │   ├── desktop.ini
#     │       │   ├── sub10C_ShirtsCompMat.csv
#     │       │   ├── sub11C_ShirtsCompMat.csv
#     │       │   ├── sub2C_ShirtsCompMat.csv
#     │       │   ├── sub3C_ShirtsCompMat.csv
#     │       │   ├── sub5C_ShirtsCompMat.csv
#     │       │   ├── sub6C_ShirtsCompMat.csv
#     │       │   ├── sub7C_ShirtsCompMat.csv
#     │       │   ├── sub8C_ShirtsCompMat.csv
#     │       │   └── sub9C_ShirtsCompMat.csv
#     │       └── desktop.ini
#     ├── CountsTable/
#     │   ├── AB/
#     │   │   ├── Cars/
#     │   │   │   ├── desktop.ini
#     │   │   │   ├── sub10AB_CarsCounts.csv
#     │   │   │   ├── sub11AB_CarsCounts.csv
#     │   │   │   ├── sub1AB_CarsCounts.csv
#     │   │   │   ├── sub2AB_CarsCounts.csv
#     │   │   │   ├── sub3AB_CarsCounts.csv
#     │   │   │   ├── sub4AB_CarsCounts.csv
#     │   │   │   ├── sub5AB_CarsCounts.csv
#     │   │   │   ├── sub6AB_CarsCounts.csv
#     │   │   │   ├── sub7AB_CarsCounts.csv
#     │   │   │   ├── sub8AB_CarsCounts.csv
#     │   │   │   └── sub9AB_CarsCounts.csv
#     │   │   ├── desktop.ini
#     │   │   └── Shirts/
#     │   │       ├── desktop.ini
#     │   │       ├── sub10AB_ShirtsCounts.csv
#     │   │       ├── sub11AB_ShirtsCounts.csv
#     │   │       ├── sub1AB_ShirtsCounts.csv
#     │   │       ├── sub2AB_ShirtsCounts.csv
#     │   │       ├── sub3AB_ShirtsCounts.csv
#     │   │       ├── sub4AB_ShirtsCounts.csv
#     │   │       ├── sub5AB_ShirtsCounts.csv
#     │   │       ├── sub6AB_ShirtsCounts.csv
#     │   │       ├── sub7AB_ShirtsCounts.csv
#     │   │       ├── sub8AB_ShirtsCounts.csv
#     │   │       └── sub9AB_ShirtsCounts.csv
#     │   ├── AC/
#     │   │   ├── Cars/
#     │   │   │   ├── desktop.ini
#     │   │   │   ├── sub10AC_CarsCounts.csv
#     │   │   │   ├── sub11AC_CarsCounts.csv
#     │   │   │   ├── sub2AC_CarsCounts.csv
#     │   │   │   ├── sub3AC_CarsCounts.csv
#     │   │   │   ├── sub5AC_CarsCounts.csv
#     │   │   │   ├── sub6AC_CarsCounts.csv
#     │   │   │   ├── sub7AC_CarsCounts.csv
#     │   │   │   ├── sub8AC_CarsCounts.csv
#     │   │   │   └── sub9AC_CarsCounts.csv
#     │   │   ├── desktop.ini
#     │   │   └── Shirts/
#     │   │       ├── desktop.ini
#     │   │       ├── sub10AC_ShirtsCounts.csv
#     │   │       ├── sub11AC_ShirtsCounts.csv
#     │   │       ├── sub2AC_ShirtsCounts.csv
#     │   │       ├── sub3AC_ShirtsCounts.csv
#     │   │       ├── sub5AC_ShirtsCounts.csv
#     │   │       ├── sub6AC_ShirtsCounts.csv
#     │   │       ├── sub7AC_ShirtsCounts.csv
#     │   │       ├── sub8AC_ShirtsCounts.csv
#     │   │       └── sub9AC_ShirtsCounts.csv
#     │   ├── BC/
#     │   │   ├── Cars/
#     │   │   │   ├── desktop.ini
#     │   │   │   ├── sub10BC_CarsCounts.csv
#     │   │   │   ├── sub11BC_CarsCounts.csv
#     │   │   │   ├── sub2BC_CarsCounts.csv
#     │   │   │   ├── sub3BC_CarsCounts.csv
#     │   │   │   ├── sub5BC_CarsCounts.csv
#     │   │   │   ├── sub6BC_CarsCounts.csv
#     │   │   │   ├── sub7BC_CarsCounts.csv
#     │   │   │   ├── sub8BC_CarsCounts.csv
#     │   │   │   └── sub9BC_CarsCounts.csv
#     │   │   ├── desktop.ini
#     │   │   └── Shirts/
#     │   │       ├── desktop.ini
#     │   │       ├── sub10BC_ShirtsCounts.csv
#     │   │       ├── sub11BC_ShirtsCounts.csv
#     │   │       ├── sub2BC_ShirtsCounts.csv
#     │   │       ├── sub3BC_ShirtsCounts.csv
#     │   │       ├── sub5BC_ShirtsCounts.csv
#     │   │       ├── sub6BC_ShirtsCounts.csv
#     │   │       ├── sub7BC_ShirtsCounts.csv
#     │   │       ├── sub8BC_ShirtsCounts.csv
#     │   │       └── sub9BC_ShirtsCounts.csv
#     │   └── desktop.ini
#     ├── desktop.ini
#     └── DistanceMeasures/
#         ├── KD/
#         │   ├── Cars/
#         │   │   ├── CarsKD.csv
#         │   │   └── desktop.ini
#         │   ├── desktop.ini
#         │   └── Shirts/
#         │       ├── desktop.ini
#         │       └── ShirtsKD.csv
#         ├── L1/
#         │   ├── Cars/
#         │   │   ├── CarsL1.csv
#         │   │   └── desktop.ini
#         │   ├── desktop.ini
#         │   └── Shirts/
#         │       ├── desktop.ini
#         │       └── ShirtsL1.csv
#         └── L2/
#             ├── Cars/
#             │   ├── CarsL2.csv
#             │   └── desktop.ini
#             ├── desktop.ini
#             └── Shirts/
#                 ├── desktop.ini
#                 └── ShirtsL2.csv

# %% [markdown]
# **CompMat** are the actual comparison matrices of the runs. Each subject and category has two, PRE/POST. Below is an example of one. Here, the convention is that the value represents the score of the column. Thus, 'Shirt1.png' won all of its competitions.

# %%
subs['sub1'].pre_ShirtsComparisonMat_df
# Out:
#             Shirt1.png Shirt2.png Shirt3.png Shirt4.png Shirt5.png Shirt6.png  \
# Shirt1.png         NaN          0          0          0          0          0
# Shirt2.png           1        NaN          0          1          1          1
# Shirt3.png           1          1        NaN          0          1          1
# Shirt4.png           1          0          1        NaN          1          1
# Shirt5.png           1          0          0          0        NaN          1
# Shirt6.png           1          0          0          0          0        NaN
# Shirt7.png           1          0          0          0          0          1
# Shirt8.png           1          0          0          1          0          0
# Shirt9.png           1          0          0          1          0          1
# Shirt10.png          1          0          0          0          0          1
# Shirt11.png          1          0          0          0          1          1
# Shirt12.png          1          0          0          1          0          0
# Shirt13.png          1          0          0          0          0          1
# Shirt14.png          1          0          0          0          0          0
# Shirt15.png          1          0          0          0          0          1
# Shirt16.png          1          0          0          0          1          0
#
#             Shirt7.png Shirt8.png Shirt9.png Shirt10.png Shirt11.png  \
# Shirt1.png           0          0          0           0           0
# Shirt2.png           1          1          1           1           1
# Shirt3.png           1          1          1           1           1
# Shirt4.png           1          0          0           1           1
# Shirt5.png           1          1          1           1           0
# Shirt6.png           0          1          0           0           0
# Shirt7.png         NaN          0          0           0           1
# Shirt8.png           1        NaN          1           1           1
# Shirt9.png           1          0        NaN           1           1
# Shirt10.png          1          0          0         NaN           0
# Shirt11.png          0          0          0           1         NaN
# Shirt12.png          1          0          1           1           0
# Shirt13.png          0          1          1           1           0
# Shirt14.png          1          1          1           1           1
# Shirt15.png          1          1          1           1           0
# Shirt16.png          1          0          0           0           0
#
#             Shirt12.png Shirt13.png Shirt14.png Shirt15.png Shirt16.png
# Shirt1.png            0           0           0           0           0
# Shirt2.png            1           1           1           1           1
# Shirt3.png            1           1           1           1           1
# Shirt4.png            0           1           1           1           1
# Shirt5.png            1           1           1           1           0
# Shirt6.png            1           0           1           0           1
# Shirt7.png            0           1           0           0           0
# Shirt8.png            1           0           0           0           1
# Shirt9.png            0           0           0           0           1
# Shirt10.png           0           0           0           0           1
# Shirt11.png           1           1           0           1           1
# Shirt12.png         NaN           1           0           1           1
# Shirt13.png           0         NaN           0           0           1
# Shirt14.png           1           1         NaN           1           1
# Shirt15.png           0           1           0         NaN           1
# Shirt16.png           0           0           0           0         NaN

# %%
# save shirts A and B
for i in subs.keys():
    subs[i].pre_ShirtsComparisonMat_df.to_csv(r"C:\Users\al33m\Box Sync\Grzywacz Lab\Experiment\forNG\Subject_Data\CompMat\Shirts\A/"
                                              +i+'A_ShirtsCompMat.csv',index=False)
    subs[i].post_ShirtsComparisonMat_df.to_csv(r"C:\Users\al33m\Box Sync\Grzywacz Lab\Experiment\forNG\Subject_Data\CompMat\Shirts\B/"
                                              +i+'B_ShirtsCompMat.csv',index=False)
    subs[i].pre_CarsComparisonMat_df.to_csv(r"C:\Users\al33m\Box Sync\Grzywacz Lab\Experiment\forNG\Subject_Data\CompMat\Cars\A/"
                                              +i+'A_CarsCompMat.csv',index=False)
    subs[i].post_CarsComparisonMat_df.to_csv(r"C:\Users\al33m\Box Sync\Grzywacz Lab\Experiment\forNG\Subject_Data\CompMat\Cars\B/"
                                              +i+'B_CarsCompMat.csv',index=False)

# %%
for i in FUPsubs.keys():
    FUPsubs[i].FUPShirtsComparisonMat.to_csv(r"C:\Users\al33m\Box Sync\Grzywacz Lab\Experiment\forNG\Subject_Data\CompMat\Shirts\C/"+
                                             i+"C_ShirtsCompMat.csv",index=False)
    FUPsubs[i].FUPCarsComparisonMat.to_csv(r"C:\Users\al33m\Box Sync\Grzywacz Lab\Experiment\forNG\Subject_Data\CompMat\Cars\C/"+
                                             i+"C_CarsCompMat.csv",index=False)

# %% [markdown]
# **CountsTable** is the frequency of counts for each item, it also has the difference between counts and rankings, for example

# %%
subs['sub1'].ShirtsCounts
# Out:
#              sub1PRE  sub1POST  DIFF  sub1_preRank  sub1_postRank  \
# Shirt1.png        15        15     0          16.0           16.0
# Shirt2.png         1         1     0           1.5            1.0
# Shirt3.png         1         2     1           1.5            3.0
# Shirt4.png         4         6     2           3.0            6.5
# Shirt5.png         5        11     6           4.5           12.0
# Shirt6.png        10        13     3          12.0           15.0
# Shirt7.png        11        10     1          13.5           11.0
# Shirt8.png         7         8     1           7.5            8.5
# Shirt9.png         8         8     0          10.0            8.5
# Shirt10.png       11        12     1          13.5           13.5
# Shirt11.png        7         6     1           7.5            6.5
# Shirt12.png        7         2     5           7.5            3.0
# Shirt13.png        9         3     6          11.0            5.0
# Shirt14.png        5         2     3           4.5            3.0
# Shirt15.png        7         9     2           7.5           10.0
# Shirt16.png       12        12     0          15.0           13.5
#
#              sub1_rankDiff
# Shirt1.png             0.0
# Shirt2.png             0.5
# Shirt3.png             1.5
# Shirt4.png             3.5
# Shirt5.png             7.5
# Shirt6.png             3.0
# Shirt7.png             2.5
# Shirt8.png             1.0
# Shirt9.png             1.5
# Shirt10.png            0.0
# Shirt11.png            1.0
# Shirt12.png            4.5
# Shirt13.png            6.0
# Shirt14.png            1.5
# Shirt15.png            2.5
# Shirt16.png            1.5

# %%
#AB
for i in subs.keys():
    subs[i].ShirtsCounts.to_csv(r"C:\Users\al33m\Box Sync\Grzywacz Lab\Experiment\forNG\Subject_Data\CountsTable\AB\Shirts/"+
                               i+"AB_ShirtsCounts.csv",index=False)
    subs[i].CarsCounts.to_csv(r"C:\Users\al33m\Box Sync\Grzywacz Lab\Experiment\forNG\Subject_Data\CountsTable\AB\Cars/"+
                               i+"AB_CarsCounts.csv",index=False)

# %%
    FUPsubs[i].CarsCounts.iloc[:,np.r_[0,2,3,5,7,9]].to_csv(r"C:\Users\al33m\Box Sync\Grzywacz Lab\Experiment\forNG\Subject_Data\CountsTable\AC\Cars/"+i+"AC_CarsCounts.csv",index=False)#AC
    FUPsubs[i].CarsCounts.iloc[:,np.r_[1,2,4,6,7,8]].to_csv(r"C:\Users\al33m\Box Sync\Grzywacz Lab\Experiment\forNG\Subject_Data\CountsTable\BC\Cars/"+i+"BC_CarsCounts.csv",index=False) #BC

# %%
for i in FUPsubs.keys():
    FUPsubs[i].ShirtsCounts.iloc[:,np.r_[0,2,3,5,7,9]].to_csv(r"C:\Users\al33m\Box Sync\Grzywacz Lab\Experiment\forNG\Subject_Data\CountsTable\AC\Shirts/"+i+"AC_ShirtsCounts.csv",index=False)#AC
    FUPsubs[i].ShirtsCounts.iloc[:,np.r_[1,2,4,6,7,8]].to_csv(r"C:\Users\al33m\Box Sync\Grzywacz Lab\Experiment\forNG\Subject_Data\CountsTable\BC\Shirts/"+i+"BC_ShirtsCounts.csv",index=False) #BC
    
    FUPsubs[i].CarsCounts.iloc[:,np.r_[0,2,3,5,7,9]].to_csv(r"C:\Users\al33m\Box Sync\Grzywacz Lab\Experiment\forNG\Subject_Data\CountsTable\AC\Cars/"+i+"AC_CarsCounts.csv",index=False)#AC
    FUPsubs[i].CarsCounts.iloc[:,np.r_[1,2,4,6,7,8]].to_csv(r"C:\Users\al33m\Box Sync\Grzywacz Lab\Experiment\forNG\Subject_Data\CountsTable\BC\Cars/"+i+"BC_CarsCounts.csv",index=False) #BC

# %% [markdown]
# # Kendall Distance

# %% [markdown]
# ## Shirts

# %%
for i in FUPsubs.keys():
    subs[i].AB_ShirtsKendallDist=choix.kendalltau_dist(subs[i].ShirtsParDF.iloc[:,0],subs[i].ShirtsParDF.iloc[:,1])/120
    FUPsubs[i].AC_ShirtsKendallDist=choix.kendalltau_dist(FUPsubs[i].ShirtsParDF.iloc[:,0],FUPsubs[i].ShirtsParDF.iloc[:,2])/120
    FUPsubs[i].BC_ShirtsKendallDist=choix.kendalltau_dist(FUPsubs[i].ShirtsParDF.iloc[:,1],FUPsubs[i].ShirtsParDF.iloc[:,2])/120

# %% [markdown]
# #### This table of 27 normalized KD values is being saved

# %%
ShirtsKD=pd.DataFrame({'subs':[i for i in FUPsubs.keys()],
             'AB':[subs[i].AB_ShirtsKendallDist for i in FUPsubs.keys()],
             'BC':[FUPsubs[i].BC_ShirtsKendallDist for i in FUPsubs.keys()],
             'AC':[FUPsubs[i].AC_ShirtsKendallDist for i in FUPsubs.keys()]})
ShirtsKD
# Out:
#     subs        AB        BC        AC
# 0   sub2  0.283333  0.283333  0.200000
# 1   sub3  0.116667  0.266667  0.250000
# 2   sub5  0.316667  0.500000  0.316667
# 3   sub6  0.191667  0.241667  0.266667
# 4   sub7  0.225000  0.150000  0.358333
# 5   sub8  0.366667  0.325000  0.308333
# 6   sub9  0.116667  0.091667  0.158333
# 7  sub10  0.175000  0.183333  0.258333
# 8  sub11  0.183333  0.125000  0.208333

# %%
plt.hist(ShirtsKD.iloc[:,1:].values.flatten())
plt.title('Shirts KD ')
plt.xlabel('kd')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
ShirtsKD.to_csv(r"C:\Users\al33m\Box Sync\Grzywacz Lab\Experiment\forNG\Subject_Data\KD\Shirts\ShirtsKD.csv",index=False)

# %% [markdown]
# #### Visualizing with an ABC triangle A=(0,0)

# %% [markdown]
# trying out a graphical method of visualizing the distances. By setting the A=[0,0], can plot a triangle because we know the lengths or distances of each of the sides to B and C. Removing axes and labels for easier visualization

# %%
def coordinates_of_triangle_given_SSS(a, b, c):
    """a, b and c are lengths of the sides of a triangle
    https://math.stackexchange.com/questions/2480560/computing-coordinates-of-vertices-in-a-sss-triangle
    """

    A = (0, 0) # coordinates of vertex A

    B = (c, 0) # coordinates of vertex B

    C_x = b * (b**2 + c**2 - a**2) / (2 * b * c)
    C_y = Decimal(b**2 - C_x**2).sqrt() # square root

    C = (float(C_x), float(C_y)) # coordinates of vertex C

    # print
    vertices = np.array([A, B, C, A])
    return(vertices)

# %%
def plotTriangle(vec):
    mylabels=['A','C','B','A']
    vertices=coordinates_of_triangle_given_SSS(vec[1],vec[0],vec[2])
#     vertices=pd.DataFrame(vertices,columns=['xval','yval'])
#     plt.plot( 'xval', 'yval', data=vertices, linestyle='-', marker='o')
    x_coords=vertices[:,0]
    y_coords=vertices[:,1]
    for i,type in enumerate(mylabels):
        x = x_coords[i]
        y = y_coords[i]
        plt.scatter(x, y, marker='o',color='black')
        plt.text(x+0.003, y+0.003,type, fontsize=9)
    plt.plot(x_coords,y_coords)

# %%
for i in np.arange(9):
    plotTriangle(ShirtsKD.loc[i][1:].values)
plt.legend([i for i in FUPsubs.keys()])
plt.title('Shirts KD ')
# Out:
# Text(0.5, 1.0, 'Shirts KD ')

# %%
fig,ax=plt.subplots()
fig.subplots_adjust(hspace=1, wspace=0.4)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
for i in range(1, 10):
    plt.subplot(3, 3, i)
    plotTriangle(ShirtsKD.loc[i-1][1:].values)
    plt.xlabel([i for i in FUPsubs.keys()][i-1])
#     plt.xlabel('B')
#     plt.ylabel('C',rotation=0)
    plt.ylim(0,0.75)
    plt.xlim(0,0.75)
    ax = plt.gca()
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.spines['left'].set_color('none')
    ax.spines['bottom'].set_color('none')

    plt.tick_params(axis='both', which='both', 
                    bottom=False, 
                    top=False, 
                    labelbottom=False, 
                    right=False, 
                    left=False, 
                    labelleft=False)
st=fig.suptitle('Shirts KD',fontsize=18)
fig.tight_layout()
# shift subplots down:
st.set_y(1)
fig.subplots_adjust(top=0.85)

# %% [markdown]
# ## Cars

# %%
for i in FUPsubs.keys():
    subs[i].AB_CarsKendallDist=choix.kendalltau_dist(subs[i].CarsParDF.iloc[:,0],subs[i].CarsParDF.iloc[:,1])/120
    FUPsubs[i].AC_CarsKendallDist=choix.kendalltau_dist(FUPsubs[i].CarsParDF.iloc[:,0],FUPsubs[i].CarsParDF.iloc[:,2])/120
    FUPsubs[i].BC_CarsKendallDist=choix.kendalltau_dist(FUPsubs[i].CarsParDF.iloc[:,1],FUPsubs[i].CarsParDF.iloc[:,2])/120

# %%
CarsKD=pd.DataFrame({'subs':[i for i in FUPsubs.keys()],
             'AB':[subs[i].AB_CarsKendallDist for i in FUPsubs.keys()],
             'BC':[FUPsubs[i].BC_CarsKendallDist for i in FUPsubs.keys()],
             'AC':[FUPsubs[i].AC_CarsKendallDist for i in FUPsubs.keys()]})
CarsKD
# Out:
#     subs        AB        BC        AC
# 0   sub2  0.191667  0.183333  0.125000
# 1   sub3  0.100000  0.116667  0.100000
# 2   sub5  0.550000  0.691667  0.575000
# 3   sub6  0.300000  0.308333  0.291667
# 4   sub7  0.141667  0.158333  0.200000
# 5   sub8  0.158333  0.225000  0.183333
# 6   sub9  0.091667  0.125000  0.100000
# 7  sub10  0.058333  0.183333  0.158333
# 8  sub11  0.141667  0.141667  0.100000

# %%
plt.hist(CarsKD.iloc[:,1:].values.flatten())
plt.title('Cars KD ')
plt.xlabel('kd')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
CarsKD.to_csv(r"C:\Users\al33m\Box Sync\Grzywacz Lab\Experiment\forNG\Subject_Data\KD\Cars\CarsKD.csv",index=False)

# %%
for i in np.arange(9):
    plotTriangle(CarsKD.loc[i][1:].values)
plt.legend([i for i in FUPsubs.keys()])
plt.title('Cars KD Norm')
# Out:
# Text(0.5, 1.0, 'Cars KD Norm')

# %%
fig,ax=plt.subplots()
fig.subplots_adjust(hspace=1, wspace=0.4)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
for i in range(1, 10):
    plt.subplot(3, 3, i)
    plotTriangle(CarsKD.loc[i-1][1:].values)
    plt.xlabel([i for i in FUPsubs.keys()][i-1])
#     plt.xlabel('B')
#     plt.ylabel('C',rotation=0)
    plt.ylim(0,0.6)
    plt.xlim(0,0.6)
    ax = plt.gca()
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.spines['left'].set_color('none')
    ax.spines['bottom'].set_color('none')

    plt.tick_params(axis='both', which='both', 
                    bottom=False, 
                    top=False, 
                    labelbottom=False, 
                    right=False, 
                    left=False, 
                    labelleft=False)
st=fig.suptitle('Cars KD',fontsize=18)
fig.tight_layout()
# shift subplots down:
st.set_y(1)
fig.subplots_adjust(top=0.85)

# %% [markdown]
# # L1 Norm

# %% [markdown]
# norm is being done on ranked data, and is normalized from 0-1 by max norm possible

# %% [markdown]
# ## Shirts

# %%
[np.linalg.norm((subs['sub2'].ShirtsCounts.iloc[:,0]-subs['sub2'].ShirtsCounts.iloc[:,1]),ord=1) for i in FUPsubs.keys()]
# Out:
# [46.0, 46.0, 46.0, 46.0, 46.0, 46.0, 46.0, 46.0, 46.0]

# %%
np.linalg.norm((subs['sub2'].ShirtsCounts.iloc[:,0]-subs['sub2'].ShirtsCounts.iloc[:,1]),ord=1)
# Out:
# 46.0

# %%
[np.linalg.norm((subs['sub2'].ShirtsCounts.iloc[:,3]-subs['sub2'].ShirtsCounts.iloc[:,4]),ord=1) for i in FUPsubs.keys()]
# Out:
# [55.0, 55.0, 55.0, 55.0, 55.0, 55.0, 55.0, 55.0, 55.0]

# %%
ShirtsL1=pd.DataFrame({'subs': [i for i in FUPsubs.keys()],
                      'AB':[np.linalg.norm((subs[i].ShirtsCounts.iloc[:,3]-subs[i].ShirtsCounts.iloc[:,4]),ord=1) for i in FUPsubs.keys()],
                      'BC':[np.linalg.norm((FUPsubs[i].ShirtsCounts.iloc[:,6]-FUPsubs[i].ShirtsCounts.iloc[:,7]),ord=1) for i in FUPsubs.keys()],
                      'AC': [np.linalg.norm((FUPsubs[i].ShirtsCounts.iloc[:,5]-FUPsubs[i].ShirtsCounts.iloc[:,7]),ord=1) for i in FUPsubs.keys()]
                      })
ShirtsL1
# Out:
#     subs    AB    BC    AC
# 0   sub2  55.0  56.0  39.0
# 1   sub3  24.0  48.0  46.0
# 2   sub5  52.0  76.0  55.0
# 3   sub6  34.0  41.0  45.0
# 4   sub7  44.0  30.0  65.0
# 5   sub8  59.0  59.0  53.0
# 6   sub9  24.0  19.0  27.0
# 7  sub10  32.0  31.0  48.0
# 8  sub11  30.0  24.0  35.0

# %%
ShirtsL1.to_csv(r"C:\Users\al33m\Google Drive\GU Neuroaesthetics Lab\forNG\Subject_Data\DistanceMeasures\L1\Shirts\ShirtsL1.csv",index=False)

# %%
plt.hist(ShirtsL1.iloc[:,1:].values.flatten())
plt.title('Shirts L1 Norm')
plt.xlabel('L1')
plt.ylabel('Freq')
# Out:
# Text(0, 0.5, 'Freq')

# %%
for i in np.arange(9):
    plotTriangle(ShirtsL1.loc[i][1:].values)
plt.legend([i for i in FUPsubs.keys()])
plt.title('Shirts L1 Norm')
# Out:
# Text(0.5, 1.0, 'Shirts L1 Norm')

# %%
fig,ax=plt.subplots()
fig.subplots_adjust(hspace=1, wspace=0.4)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
for i in range(1, 10):
    plt.subplot(3, 3, i)
    plotTriangle(ShirtsL1.loc[i-1][1:].values)
    plt.xlabel([i for i in FUPsubs.keys()][i-1])
#     plt.xlabel('B')
#     plt.ylabel('C',rotation=0)
    plt.ylim(0,0.75)
    plt.xlim(0,0.75)
    ax = plt.gca()
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.spines['left'].set_color('none')
    ax.spines['bottom'].set_color('none')

    plt.tick_params(axis='both', which='both', 
                    bottom=False, 
                    top=False, 
                    labelbottom=False, 
                    right=False, 
                    left=False, 
                    labelleft=False)
st=fig.suptitle('Shirts L1',fontsize=18)
fig.tight_layout()
# shift subplots down:
st.set_y(1)
fig.subplots_adjust(top=0.85)

# %% [markdown]
# ## Cars

# %%
CarsL1=pd.DataFrame({'subs': [i for i in FUPsubs.keys()],
                      'AB':[np.linalg.norm((subs[i].CarsCounts.iloc[:,3]-subs[i].CarsCounts.iloc[:,4]),ord=1)/128 for i in FUPsubs.keys()],
                      'BC':[np.linalg.norm((FUPsubs[i].CarsCounts.iloc[:,6]-FUPsubs[i].CarsCounts.iloc[:,7]),ord=1)/128 for i in FUPsubs.keys()],
                      'AC': [np.linalg.norm((FUPsubs[i].CarsCounts.iloc[:,5]-FUPsubs[i].CarsCounts.iloc[:,7]),ord=1)/128 for i in FUPsubs.keys()]
                      })
CarsL1
# Out:
#     subs        AB        BC        AC
# 0   sub2  0.281250  0.273438  0.171875
# 1   sub3  0.187500  0.226562  0.171875
# 2   sub5  0.648438  0.937500  0.757812
# 3   sub6  0.437500  0.429688  0.398438
# 4   sub7  0.218750  0.226562  0.281250
# 5   sub8  0.226562  0.304688  0.281250
# 6   sub9  0.164062  0.187500  0.148438
# 7  sub10  0.109375  0.234375  0.226562
# 8  sub11  0.203125  0.234375  0.132812

# %%
CarsL1.to_csv(r"C:\Users\al33m\Google Drive\GU Neuroaesthetics Lab\forNG\Subject_Data\DistanceMeasures\L1\Cars\CarsL1.csv",index=False)

# %%
plt.hist(CarsL1.iloc[:,1:].values.flatten())
plt.title('Cars L1 Norm')
plt.xlabel('L1')
plt.ylabel('Freq')
# Out:
# Text(0, 0.5, 'Freq')

# %%
for i in np.arange(9):
    plotTriangle(CarsL1.loc[i][1:].values)
plt.legend([i for i in FUPsubs.keys()])
plt.title('Cars L1 Norm')
# Out:
# Text(0.5, 1.0, 'Cars L1 Norm')

# %%
fig,ax=plt.subplots()
fig.subplots_adjust(hspace=1, wspace=0.4)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
for i in range(1, 10):
    plt.subplot(3, 3, i)
    plotTriangle(CarsL1.loc[i-1][1:].values)
    plt.xlabel([i for i in FUPsubs.keys()][i-1])
#     plt.xlabel('B')
#     plt.ylabel('C',rotation=0)
    plt.ylim(0,0.75)
    plt.xlim(0,0.75)
    ax = plt.gca()
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.spines['left'].set_color('none')
    ax.spines['bottom'].set_color('none')

    plt.tick_params(axis='both', which='both', 
                    bottom=False, 
                    top=False, 
                    labelbottom=False, 
                    right=False, 
                    left=False, 
                    labelleft=False)
st=fig.suptitle('Cars L1',fontsize=18)
fig.tight_layout()
# shift subplots down:
st.set_y(1)
fig.subplots_adjust(top=0.85)

# %% [markdown]
# # L2 Norm

# %% [markdown]
# done on ranks and normalized by maximum possible 36.878

# %% [markdown]
# ## Shirts

# %%
ShirtsL2=pd.DataFrame({'subs': [i for i in FUPsubs.keys()],
                      'AB':[np.linalg.norm((subs[i].ShirtsCounts.iloc[:,3]-subs[i].ShirtsCounts.iloc[:,4]),ord=2)/36.878 for i in FUPsubs.keys()],
                      'BC':[np.linalg.norm((FUPsubs[i].ShirtsCounts.iloc[:,6]-FUPsubs[i].ShirtsCounts.iloc[:,7]),ord=2)/36.878 for i in FUPsubs.keys()],
                      'AC': [np.linalg.norm((FUPsubs[i].ShirtsCounts.iloc[:,5]-FUPsubs[i].ShirtsCounts.iloc[:,7]),ord=2)/36.878 for i in FUPsubs.keys()]
                      })
ShirtsL2
# Out:
#     subs        AB        BC        AC
# 0   sub2  0.439337  0.422703  0.361270
# 1   sub3  0.198340  0.458981  0.416129
# 2   sub5  0.478204  0.685462  0.458180
# 3   sub6  0.283753  0.378175  0.411688
# 4   sub7  0.384442  0.237946  0.555722
# 5   sub8  0.526855  0.514141  0.462572
# 6   sub9  0.197411  0.176778  0.283104
# 7  sub10  0.295805  0.323130  0.428749
# 8  sub11  0.337597  0.199264  0.313309

# %%
ShirtsL2.to_csv(r"C:\Users\al33m\Google Drive\GU Neuroaesthetics Lab\forNG\Subject_Data\DistanceMeasures\L2\Shirts\ShirtsL2.csv",index=False)

# %%
plt.hist(ShirtsL2.iloc[:,1:].values.flatten())
plt.title('Shirts L2 Norm')
plt.xlabel('l2')
plt.ylabel('Freq')
# Out:
# Text(0, 0.5, 'Freq')

# %%
for i in np.arange(9):
    plotTriangle(ShirtsL2.loc[i][1:].values)
plt.legend([i for i in FUPsubs.keys()])
plt.title('Shirts L2 Norm')
# Out:
# Text(0.5, 1.0, 'Shirts L2 Norm')

# %%
fig,ax=plt.subplots()
fig.subplots_adjust(hspace=1, wspace=0.4)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
for i in range(1, 10):
    plt.subplot(3, 3, i)
    plotTriangle(ShirtsL2.loc[i-1][1:].values)
    plt.xlabel([i for i in FUPsubs.keys()][i-1])
#     plt.xlabel('B')
#     plt.ylabel('C',rotation=0)
    plt.ylim(0,0.75)
    plt.xlim(0,0.75)
    ax = plt.gca()
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.spines['left'].set_color('none')
    ax.spines['bottom'].set_color('none')

    plt.tick_params(axis='both', which='both', 
                    bottom=False, 
                    top=False, 
                    labelbottom=False, 
                    right=False, 
                    left=False, 
                    labelleft=False)
st=fig.suptitle('Shirts L2',fontsize=18)
fig.tight_layout()
# shift subplots down:
st.set_y(1)
fig.subplots_adjust(top=0.85)

# %% [markdown]
# ## Cars

# %%
CarsL2=pd.DataFrame({'subs': [i for i in FUPsubs.keys()],
                      'AB':[np.linalg.norm((subs[i].CarsCounts.iloc[:,3]-subs[i].CarsCounts.iloc[:,4]),ord=2)/36.878 for i in FUPsubs.keys()],
                      'BC':[np.linalg.norm((FUPsubs[i].CarsCounts.iloc[:,6]-FUPsubs[i].CarsCounts.iloc[:,7]),ord=2)/36.878 for i in FUPsubs.keys()],
                      'AC': [np.linalg.norm((FUPsubs[i].CarsCounts.iloc[:,5]-FUPsubs[i].CarsCounts.iloc[:,7]),ord=2)/36.878 for i in FUPsubs.keys()]
                      })
CarsL2
# Out:
#     subs        AB        BC        AC
# 0   sub2  0.299511  0.315065  0.208285
# 1   sub3  0.230091  0.267066  0.207401
# 2   sub5  0.751962  0.892786  0.767687
# 3   sub6  0.473956  0.462174  0.414802
# 4   sub7  0.283753  0.253651  0.331553
# 5   sub8  0.253651  0.340848  0.297664
# 6   sub9  0.175735  0.212652  0.152191
# 7  sub10  0.139590  0.264993  0.237946
# 8  sub11  0.215230  0.237946  0.150978

# %%
CarsL2.to_csv(r"C:\Users\al33m\Google Drive\GU Neuroaesthetics Lab\forNG\Subject_Data\DistanceMeasures\L2\Cars\CarsL2.csv",index=False)

# %%
plt.hist(CarsL2.iloc[:,1:].values.flatten())
plt.title('Cars L2 Norm')
plt.xlabel('l2')
plt.ylabel('Freq')
# Out:
# Text(0, 0.5, 'Freq')

# %%
for i in np.arange(9):
    plotTriangle(CarsL2.loc[i][1:].values)
plt.legend([i for i in FUPsubs.keys()])
plt.title('Cars L2 Norm')
# Out:
# Text(0.5, 1.0, 'Cars L2 Norm')

# %%
fig,ax=plt.subplots()
fig.subplots_adjust(hspace=1, wspace=0.4)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
for i in range(1, 10):
    plt.subplot(3, 3, i)
    plotTriangle(CarsL2.loc[i-1][1:].values)
    plt.xlabel([i for i in FUPsubs.keys()][i-1])
#     plt.xlabel('B')
#     plt.ylabel('C',rotation=0)
    plt.ylim(0,0.75)
    plt.xlim(0,0.75)
    ax = plt.gca()
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.spines['left'].set_color('none')
    ax.spines['bottom'].set_color('none')

    plt.tick_params(axis='both', which='both', 
                    bottom=False, 
                    top=False, 
                    labelbottom=False, 
                    right=False, 
                    left=False, 
                    labelleft=False)
st=fig.suptitle('Cars L2',fontsize=18)
fig.tight_layout()
# shift subplots down:
st.set_y(1)
fig.subplots_adjust(top=0.85)
